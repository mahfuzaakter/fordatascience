# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset('titanic')
titanic
titanic.iloc[:5:]
# titanic.set_index('column_name', inplace=True)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips = sns.load_dataset('tips')
tips
tips.iloc[:5:]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris = sns.load_dataset('iris')
iris
iris.iloc[:5:]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex',height=4.5)

# %%
sns.boxplot(x="day", y="total_bill", data=tips,
           hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Define a custom color palette
custom_palette = {"Male": "blue", "Female": "pgreen"}

# Create the boxplot with the custom palette
sns.boxplot(x="day", y="total_bill", data=tips, hue='sex', palette=custom_palette)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\anaconda\Lib\site-packages\seaborn\palettes.py:251, in color_palette(palette, n_colors, desat, as_cmap)
#     250     palette = map(mpl.colors.colorConverter.to_rgb, palette)
# --> 251     palette = _ColorPalette(palette)
#     252 except ValueError:
#
# File D:\anaconda\Lib\site-packages\matplotlib\colors.py:496, in to_rgb(c)
#     495 """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 496 return to_rgba(c)[:3]
#
# File D:\anaconda\Lib\site-packages\matplotlib\colors.py:299, in to_rgba(c, alpha)
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#
# File D:\anaconda\Lib\site-packages\matplotlib\colors.py:374, in _to_rgba_no_colorcycle(c, alpha)
# ...

# %%
sns.boxplot(x="day", y="tip", data=tips, hue='sex', palette=['g','b'])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 3))
sns.boxplot(x="class", y="age", data=titanic, hue='alive',palette="coolwarm")
plt.show()

# %%
sns.boxplot(x="class", y="age", data=titanic, hue='alive',palette="coolwarm")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
titanic = sns.load_dataset('titanic')
sns.distplot(titanic["fare"],kde=False,bins=20,color="green")
# plt.xlabek("fare")
# Out:
# C:\Users\DCL\AppData\Local\Temp\ipykernel_12008\3390947321.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["fare"],kde=False,bins=20,color="green")
# <Axes: xlabel='fare'>

# %%
sns.jointplot(x='fare',y='age',data=titanic,height=4.5)

# %%
sns.boxplot(x="class", y="age", data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
titanic = sns.load_dataset('titanic')
sns.distplot( titanic["sex"],bins=20)
# Out:
# C:\Users\DCL\AppData\Local\Temp\ipykernel_12008\4248402056.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( titanic["sex"],bins=20)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 2
#       1 titanic = sns.load_dataset('titanic')
# ----> 2 sns.distplot( titanic["sex"],bins=20)
#
# File D:\anaconda\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
# ...

# %%
titanic_corr=titanic.corr()
sns.heatmap(titanic_corr,cmap='coolwarm',annot=True)
plt.title('titanic_corr()')
# Out:
# C:\Users\DCL\AppData\Local\Temp\ipykernel_12008\248591601.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic_corr=titanic.corr()
# Text(0.5, 1.0, 'titanic_corr()')

# %%
tips[tips['day']]['total_bill'].count()
sns.barplot(x="sex",  hue="class",data=titanic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 sns.barplot(x="sex",  hue="class",data=titanic)
#
# File D:\anaconda\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
sns.countplot(x="sex", data=titanic,hue="class",palette=['b','g','red'],saturation=0.3)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="sex", data=titanic,hue="class",palette="Reds_r")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips = sns.load_dataset('tips')
tips
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tips = sns.load_dataset('tips')
#       2 tips
#
# NameError: name 'sns' is not defined
